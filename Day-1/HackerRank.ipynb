# %%
if __name__ == '__main__':
    N = int(input().strip())
    if N % 2 !=0:
        print("Weird")
    elif 2 <= N <= 6:
        print("Not Weird")
    elif 8 <= N <= 20:
        print("Weird but not weird")
    else:
        print(f"entered {N} which is > 20 and even number")
# Out:
# entered 800 which is > 20 and even number
